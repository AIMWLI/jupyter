# %% [markdown]
# # Jupyter Notebook 快捷键 (Keymaps)
#
# ---
#
# ## 一、编辑模式 (Edit Mode) — 按 `Enter` 进入
#
# | 快捷键 | 作用 |
# |--------|------|
# | `Tab` | 代码补全 / 缩进 |
# | `Shift + Tab` | 显示函数文档/签名 |
# | `Cmd + /` (Mac) / `Ctrl + /` | 注释 / 取消注释选中行 |
# | `Cmd + Shift + -` | 从光标处拆分当前单元格 |
# | `Cmd + Z` | 撤销 |
# | `Cmd + Shift + Z` | 重做 |
# | `Home` / `End` | 跳至行首 / 行尾 |
# | `Cmd + →` / `Cmd + ←` | 跳至行尾 / 行首 |
# | `Cmd + Enter` | 运行当前单元格（不移动焦点） |
#
# ---
#
# ## 二、命令模式 (Command Mode) — 按 `Esc` 进入
#
# ### 单元格类型
# | 快捷键 | 作用 |
# |--------|------|
# | `Y` | 切换为 **Code** 单元格 |
# | `M` | 切换为 **Markdown** 单元格 |
# | `R` | 切换为 **Raw** 单元格 |
#
# ### 新建与删除
# | 快捷键 | 作用 |
# |--------|------|
# | `A` | 当前单元格 **上方** 新建 |
# | `B` | 当前单元格 **下方** 新建 |
# | `D D` (连按两次 D) | **删除** 当前单元格 |
# | `Z` | 撤销删除 |
#
# ### 剪切、复制、粘贴
# | 快捷键 | 作用 |
# |--------|------|
# | `X` | 剪切当前单元格 |
# | `C` | 复制当前单元格 |
# | `V` | 粘贴到 **下方** |
# | `Shift + V` | 粘贴到 **上方** |
#
# ### 移动与选中
# | 快捷键 | 作用 |
# |--------|------|
# | `↑` / `↓` | 向上 / 向下移动焦点 |
# | `Shift + ↑` / `Shift + ↓` | 选中多个单元格 |
# | `Shift + K` / `Shift + J` | 扩展选中上方 / 下方 |
# | `Ctrl + Shift + ↑` / `↓` | 上移 / 下移当前单元格 |
#
# ### 显示与运行
# | 快捷键 | 作用 |
# |--------|------|
# | `Shift + Enter` | 运行并选中下方单元格 |
# | `Ctrl + Enter` | 运行当前单元格 |
# | `Option + Enter` | 运行并在下方新建 |
# | `L` | 显示 / 隐藏行号 |
# | `H` | 显示快捷键帮助 |
# | `S` | 保存 Notebook |
#
# ---
#
# ## 三、菜单操作
#
# | 操作 | 路径 |
# |------|------|
# | 运行全部 | `Cell` → `Run All` |
# | 运行以上全部 | `Cell` → `Run All Above` |
# | 运行以下全部 | `Cell` → `Run All Below` |
# | 清空输出 | `Cell` → `Current Outputs` → `Clear` |
# | 重启内核 | `Kernel` → `Restart & Run All` |
# | 导出 HTML/Python | `File` → `Download As` |
#
# ---
#
# ## 四、Magic 命令 (IPython 特有)
#
# | 命令 | 作用 |
# |------|------|
# | `%run script.py` | 运行外部 Python 脚本 |
# | `%load script.py` | 将外部脚本内容加载到单元格 |
# | `%time` | 测量单行代码执行时间 |
# | `%timeit` | 多次运行取平均时间 |
# | `%%timeit` | 测量整个单元格的多次运行时间 |
# | `%who` | 列出当前所有变量 |
# | `%whos` | 列出变量及详细信息 |
# | `%env` | 查看 / 设置环境变量 |
# | `%pwd` | 查看当前工作目录 |
# | `%ls` | 列出目录文件 |
# | `%matplotlib inline` | 使图表直接显示在 Notebook 中 |
#
# ---
#
# > **Tip:** 按 `H` 可在 Notebook 中查看完整快捷键列表。

# %%
# ============================================================
# Python 基础 — 变量与数据类型
# ============================================================

# --- 变量赋值 ---
name = "Python"          # str
version = 3.12           # float
year = 1991              # int
is_fun = True            # bool
nothing = None           # NoneType

print(f"{name}, version {version}, born in {year}")
print(f"Type check: name is str -> {isinstance(name, str)}")
print(f"None: {nothing}")

# --- 类型转换 ---
print("\n--- Type Casting ---")
print(int(3.14))         # 3
print(float(42))         # 42.0
print(str(100))          # "100"
print(bool(1), bool(0))  # True False

# --- 多变量赋值 ---
a, b, c = 1, 2, 3
x = y = z = 0
print(f"Swap: a={a}, b={b} -> ", end="")
a, b = b, a              # 交换
print(f"a={a}, b={b}")

# --- 运算符 ---
print("\n--- Operators ---")
print(f"10 / 3  = {10 / 3}")    # 3.333... (真除法)
print(f"10 // 3 = {10 // 3}")   # 3 (整除)
print(f"10 % 3  = {10 % 3}")    # 1 (取余)
print(f"10 ** 3 = {10 ** 3}")   # 1000 (幂)
print(f"and/or: {True and False}, {True or False}")
print(f"is: {type(42) is int}")
print(f"in: {'th' in 'Python'}")
# Out:
# Python, version 3.12, born in 1991
# Type check: name is str -> True
# None: None
#
# --- Type Casting ---
# 3
# 42.0
# 100
# True False
# Swap: a=1, b=2 -> a=2, b=1
#
# --- Operators ---
# 10 / 3  = 3.3333333333333335
# 10 // 3 = 3
# 10 % 3  = 1
# 10 ** 3 = 1000
# and/or: False, True
# is: True
# in: True

# %%
# ============================================================
# Python 基础 — 字符串 (String)
# ============================================================

# --- 创建字符串 ---
s1 = "Hello"
s2 = 'World'
s3 = """Multi-line\nstring"""
print(s1, s2)
print(s3)

# --- 常用操作 ---
text = "  Python Programming  "
print(f"len:        {len(text)}")
print(f"lower:      '{text.lower()}'")
print(f"upper:      '{text.upper()}'")
print(f"strip:      '{text.strip()}'")
print(f"replace:    '{text.replace('Python', 'Java')}'")
print(f"split:      {text.strip().split()}")
print(f"join:       {'-'.join(['a', 'b', 'c'])}")
print(f"startswith: {text.strip().startswith('Python')}")
print(f"find:       {text.find('Prog')}")

# --- 索引与切片 [start:stop:step] ---
word = "Python"
print(f"\n--- Slicing '{word}' ---")
print(f"[0]:    {word[0]}")       # P
print(f"[-1]:   {word[-1]}")      # n
print(f"[1:4]:  {word[1:4]}")     # yth
print(f"[:3]:   {word[:3]}")      # Pyt
print(f"[3:]:   {word[3:]}")      # hon
print(f"[::-1]: {word[::-1]}")    # nohtyP (反转)
print(f"[::2]:  {word[::2]}")     # Pto (步长2)

# --- f-string (推荐) ---
name, score = "Alice", 95.5
print("\n--- f-string ---")
print(f"{name=}, {score=}")              # 调试输出
print(f"{name} scored {score:.1f}%")     # 格式化小数
print(f"{score:>10.1f}")                 # 右对齐占10位
print(f"{'Python':_<10}")                # 左对齐填充
# Out:
# Hello World
# Multi-line
# string
# len:        22
# lower:      '  python programming  '
# upper:      '  PYTHON PROGRAMMING  '
# strip:      'Python Programming'
# replace:    '  Java Programming  '
# split:      ['Python', 'Programming']
# join:       a-b-c
# startswith: True
# find:       9
#
# --- Slicing 'Python' ---
# [0]:    P
# [-1]:   n
# [1:4]:  yth
# [:3]:   Pyt
# [3:]:   hon
# [::-1]: nohtyP
# [::2]:  Pto
#
# --- f-string ---
# name='Alice', score=95.5
# Alice scored 95.5%
#       95.5
# Python____

# %%
# ============================================================
# Python 基础 — 列表 & 字典
# ============================================================

# --- 列表 (list) ---
nums = [3, 1, 4, 1, 5]
print(f"list:     {nums}")
print(f"len:      {len(nums)}")
print(f"index 2:  {nums[2]}")
print(f"append 9: {nums + [9]}")     # 不修改原列表

nums.append(9)                         # 原地修改
nums.sort()
print(f"sorted:   {nums}")
print(f"pop:      {nums.pop()}")       # 弹出末尾
print(f"after pop:{nums}")

# --- 列表切片 ---
print("\n-- Slicing --")
print(f"[:3]:   {nums[:3]}")
print(f"[::2]:  {nums[::2]}")

# --- 列表推导式 ---
squares = [x**2 for x in range(5)]
evens   = [x for x in range(10) if x % 2 == 0]
print(f"\nsquares:  {squares}")
print(f"evens:    {evens}")

# --- 元组 (tuple) 不可变 ---
point = (3, 4)
x, y = point                          # 解包
print(f"\ntuple:    {point}, x={x}, y={y}")

# --- 字典 (dict) ---
user = {"name": "Alice", "age": 25, "city": "Beijing"}
print(f"\ndict:     {user}")
print(f"name:     {user['name']}")
print(f"keys:     {list(user.keys())}")
print(f"values:   {list(user.values())}")
user["job"] = "Engineer"              # 新增/修改
print(f"updated:  {user}")

# get() 安全取值
print(f"country:  {user.get('country', 'N/A')}")

# 遍历
for k, v in user.items():
    print(f"  {k} = {v}")
# Out:
# list:     [3, 1, 4, 1, 5]
# len:      5
# index 2:  4
# append 9: [3, 1, 4, 1, 5, 9]
# sorted:   [1, 1, 3, 4, 5, 9]
# pop:      9
# after pop:[1, 1, 3, 4, 5]
#
# -- Slicing --
# [:3]:   [1, 1, 3]
# [::2]:  [1, 3, 5]
#
# squares:  [0, 1, 4, 9, 16]
# evens:    [0, 2, 4, 6, 8]
#
# tuple:    (3, 4), x=3, y=4
#
# dict:     {'name': 'Alice', 'age': 25, 'city': 'Beijing'}
# name:     Alice
# keys:     ['name', 'age', 'city']
# values:   ['Alice', 25, 'Beijing']
# updated:  {'name': 'Alice', 'age': 25, 'city': 'Beijing', 'job': 'Engineer'}
# country:  N/A
#   name = Alice
#   age = 25
#   city = Beijing
#   job = Engineer

# %%
# ============================================================
# Python 基础 — 控制流 (if / for / while)
# ============================================================

# --- if / elif / else ---
score = 85
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
else:
    grade = "D"
print(f"Score: {score} -> Grade: {grade}")

# 三元表达式
age = 20
status = "成人" if age >= 18 else "未成年"
print(f"{age}岁 -> {status}")

# --- for 循环 ---
print("\n--- for loop ---")
for i in range(3):
    print(f"  range({i})", end="")
print()

fruits = ["apple", "banana", "cherry"]
for idx, fruit in enumerate(fruits, start=1):
    print(f"  {idx}: {fruit}")

# 同时遍历两个列表
names = ["Alice", "Bob", "Charlie"]
scores = [85, 92, 78]
for n, s in zip(names, scores):
    print(f"  {n}: {s}")

# --- while 循环 ---
print("\n--- while loop ---")
n = 5
while n > 0:
    print(f"  {n}", end="")
    n -= 1
print("  Go!")

# break / continue
for i in range(10):
    if i == 3:
        continue       # 跳过 3
    if i == 7:
        break          # 到 7 停止
    print(f"  {i}", end="")
print("  (skip 3, stop at 7)")
# Out:
# Score: 85 -> Grade: B
# 20岁 -> 成人
#
# --- for loop ---
#   range(0)  range(1)  range(2)
#   1: apple
#   2: banana
#   3: cherry
#   Alice: 85
#   Bob: 92
#   Charlie: 78
#
# --- while loop ---
#   5  4  3  2  1  Go!
#   0  1  2  4  5  6  (skip 3, stop at 7)

# %%
# ============================================================
# Python 基础 — 函数 (Function)
# ============================================================

# --- 基本函数 ---
def greet(name):
    return f"Hello, {name}!"

print(greet("Alice"))


# --- 默认参数 & 类型注解 (3.5+) ---
def power(base: int, exp: int = 2) -> int:
    return base ** exp

print(f"power(3)    = {power(3)}")       # 9
print(f"power(2, 4) = {power(2, 4)}")    # 16


# --- *args (可变位置参数) ---
def sum_all(*args) -> float:
    return sum(args)

print(f"sum_all(1,2,3,4) = {sum_all(1, 2, 3, 4)}")


# --- **kwargs (可变关键字参数) ---
def print_info(**kwargs):
    for k, v in kwargs.items():
        print(f"  {k} = {v}")

print_info(name="Bob", age=30, city="Shanghai")


# --- 返回值: 多值返回 (实为元组) ---
def min_max(items):
    return min(items), max(items)

low, high = min_max([3, 1, 7, 2, 9])
print(f"min_max -> low={low}, high={high}")


# --- Lambda 匿名函数 ---
square = lambda x: x ** 2
print(f"lambda square(5) = {square(5)}")

pairs = [(1, "c"), (2, "a"), (3, "b")]
pairs.sort(key=lambda p: p[1])  # 按第二个元素排序
print(f"sorted by letter: {pairs}")
# Out:
# Hello, Alice!
# power(3)    = 9
# power(2, 4) = 16
# sum_all(1,2,3,4) = 10
#   name = Bob
#   age = 30
#   city = Shanghai
# min_max -> low=1, high=9
# lambda square(5) = 25
# sorted by letter: [(2, 'a'), (3, 'b'), (1, 'c')]

# %%
# ============================================================
# Python 基础 — 集合 & 常用内置函数
# ============================================================

# --- 集合 (set) 无序不重复 ---
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

print(f"a:          {a}")
print(f"b:          {b}")
print(f"a | b (并): {a | b}")    # union
print(f"a & b (交): {a & b}")    # intersection
print(f"a - b (差): {a - b}")    # difference
print(f"a ^ b (异): {a ^ b}")    # symmetric diff

# 去重
dupes = [1, 2, 2, 3, 1, 4]
unique = list(set(dupes))
print(f"\ndedup: {dupes} -> {unique}")


# --- 常用内置函数 ---
nums = [3, 1, 4, 1, 5, 9, 2]
print(f"\nnums:       {nums}")
print(f"len:        {len(nums)}")
print(f"sum:        {sum(nums)}")
print(f"max:        {max(nums)}")
print(f"min:        {min(nums)}")
print(f"sorted:     {sorted(nums)}")
print(f"reversed:   {list(reversed(nums))}")
print(f"any > 5:    {any(x > 5 for x in nums)}")
print(f"all > 0:    {all(x > 0 for x in nums)}")
print(f"map(x**2):  {list(map(lambda x: x**2, nums[:4]))}")
print(f"filter odd: {list(filter(lambda x: x % 2 == 1, nums[:4]))}")
# Out:
# a:          {1, 2, 3, 4}
# b:          {3, 4, 5, 6}
# a | b (并): {1, 2, 3, 4, 5, 6}
# a & b (交): {3, 4}
# a - b (差): {1, 2}
# a ^ b (异): {1, 2, 5, 6}
#
# dedup: [1, 2, 2, 3, 1, 4] -> [1, 2, 3, 4]
#
# nums:       [3, 1, 4, 1, 5, 9, 2]
# len:        7
# sum:        25
# max:        9
# min:        1
# sorted:     [1, 1, 2, 3, 4, 5, 9]
# reversed:   [2, 9, 5, 1, 4, 1, 3]
# any > 5:    True
# all > 0:    True
# map(x**2):  [9, 1, 16, 1]
# filter odd: [3, 1, 1]

# %%
# ============================================================
# Python 基础 — 文件 I/O & 异常处理
# ============================================================

# --- 写文件 ---
with open("/tmp/demo.txt", "w", encoding="utf-8") as f:
    f.write("Hello Python\n")
    f.write("Line 2\n")

# --- 读文件 ---
with open("/tmp/demo.txt", "r", encoding="utf-8") as f:
    content = f.read()
print(f"File content:\n{content}")

# 逐行读取
with open("/tmp/demo.txt", "r") as f:
    for line in f:
        print(f"  line: {line.strip()}")

# --- 异常处理 ---
print("\n--- Exception Handling ---")

def divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("  Error: division by zero!")
    except TypeError as e:
        print(f"  TypeError: {e}")
    else:
        print(f"  {a} / {b} = {result}")
    finally:
        print("  (cleanup: always runs)")

divide(10, 2)
divide(10, 0)
divide(10, "a")
# Out:
# File content:
# Hello Python
# Line 2
#
#   line: Hello Python
#   line: Line 2
#
# --- Exception Handling ---
#   10 / 2 = 5.0
#   (cleanup: always runs)
#   Error: division by zero!
#   (cleanup: always runs)
#   TypeError: unsupported operand type(s) for /: 'int' and 'str'
#   (cleanup: always runs)

# %%
# %run "/Users/songjin/IdeaProjects/jupyter/keymaps.ipynb"
