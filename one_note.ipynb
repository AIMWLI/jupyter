# %% [markdown]
# # Python 基础
#
# 随手记的一些 Python 基础操作，备忘用。

# %% [markdown]
# ## 变量与基本类型

# %%
# 数值
a = 3
b = 4
print(f"a + b = {a + b}")
print(f"a / b = {a / b}")  # 浮点除法
print(f"a // b = {a // b}")  # 整数除法
print(f"a ** b = {a ** b}")  # 幂运算

# 字符串
name = "Python"
version = 3.12
print(f"Hello {name} {version}")

# 布尔
is_ok = True
print(f"not is_ok = {not is_ok}")

# %% [markdown]
# ## 列表与字典

# %%
# 列表操作
nums = [1, 3, 5, 7, 9]
nums.append(11)
nums.insert(0, 0)
print(f"列表: {nums}")
print(f"切片 [1:4]: {nums[1:4]}")
print(f"步长 [::2]: {nums[::2]}")

# 列表推导式
squares = [x**2 for x in range(10) if x % 2 == 0]
print(f"偶数平方: {squares}")

# 字典
info = {"name": "Alice", "age": 25, "city": "Tokyo"}
info["job"] = "Engineer"
print(f"字典: {info}")
print(f"keys: {list(info.keys())}")

# 解包
a, b, *rest = [1, 2, 3, 4, 5]
print(f"a={a}, b={b}, rest={rest}")
